# %% [markdown]
# <a href="https://colab.research.google.com/github/aledigo/Modelos_ML_Python/blob/main/NubeSanJuan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wordcloud matplotlib

from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_wordcloud(word_list, title):
    stopwords = set([
        'los', 'las', 'es','lo','el','la','que', 'su', 'de', 'y', 'en', 'Qué','etc', 'con','por','me', 'más','del',
    ])
    wordcloud = WordCloud(width=1080, height=1080, stopwords=stopwords).generate(' '.join(word_list))

    plt.figure(figsize=(10, 10))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(title)
    plt.show()

SanJuan = [
    'Sol',
    'aire puro',
    'tranquilidad mucha Seguridad.',
    'calidez',  'personas', 'paisajes',
    'paisajes',
    'paisajes',
    'Gente',
    'gente  preserva cultura sanjuanina',
    ' gustarme', 'especial' , 'realmente', 'gusta', 'todo', 'gusta',
    'verano',
     'Tranquilidad',
    'bello Calingasta',
    'costanera',
    'paisajes', 'montaña',
    'montañas de ullum',
    'plaza 25 de Mayo',
    'Paisajes', 'gente',
    'paisajes',
    ' imponente' 'paisajes',  'calidez', 'gente', 'montañas', 'Belleza', 'Natural', 'tiempo',  'provincia', 'única',
    'Sol', 'días',
    'ciudad','capital',
    'Montañas', 'Diques',
    'Calingasta',
    'Montañas',
    'Paisaje',
    'Cascada Santa Clara',
    'paisajes', 'valle', 'luna', 'Iglesia, calingasta',
    'Gente',  'geografía',
    'Sol', 'Otoño',
    'Solidaridad', 'respeto', 'amor', 'projimo' , 'vecinos' , 'seguridad',  'comunal', 'clima', 'bellos', 'paisajes',
    'Su gente', 'paisajes',  'clima', 'sol' ,
    'Agua Negra', 'paisajes', 'hermosos', 'San Juan',  'belleza', 'impactante','montañas','vegetación' ,'frescura',
    'cristalina  vertientes  perfecta  desarrollar  sentidos, disfrutar  descansar',
    'calidez', 'gente', 'provincia',
    'clima',
    'Vino',
    'Sol', 'asados', 'buen vino', 'juntadas' , 'familia', 'amigos',
    'Todo', 'gente', 'paisajes, tranquilidad',
    'Caminar', 'calles',
    'Su clima',
    'Provincia', 'segura', 'tranquilidad', 'valle fértil',
    'Montañas',
    'otoño', 'sol', 'gente', 'tranquilidad',
    'Paisajes',
    'Gente',
    'familia',
    'comidas', 'lugares', 'pachatas', 'compartir', 'buenos', 'mates',
    'familia', 'amigos', 'gusta' , 'San Juan']
title = 'Me gusta de San Juan'

generate_wordcloud(SanJuan, title)
